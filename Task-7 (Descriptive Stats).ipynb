# %% [markdown]
# # DESCRIPTIVE STATISTICS
# Descriptive statistics summarizes or describes **characteristics** of a data set.
# Descriptive statistics consists of two basic categories of measures: **measures of central tendency** and **measures of variability (or spread).**
# Measures of central tendency describe the center of a data set.
# Measures of variability or spread describe the dispersion of data within the set.
#
# $$ TASKS $$

# %% [markdown]
# Step 1: Import the Libraries

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import scoreatpercentile
from scipy.stats import norm
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import probplot
import pylab

# %% [markdown]
# Step 2: Import the Dataset and understand it

# %%
Dataset = pd.read_csv('data.csv')
Dataset.head(10)
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
# 5            14000              8000                  2                0
# 6            15000             16000                  3            35000
# 7            18000             20000                  5             8000
# 8            19000              9000                  2                0
# 9            20000              9000                  4                0
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# ...

# %%
Dataset.shape
# Out:
# (50, 7)

# %% [markdown]
# The Dataset has **50 Rows** and **7 Columns**.

# %% [markdown]
# Step 3: Calculation of Mean, Median and Mode (Measures of Central tendancy)

# %% [markdown]
# 1. Monthly HH Income

# %%
Mthly_HH_Income = Dataset['Mthly_HH_Income'].values
print ('Maximum Monthly HH Income would be : ', Mthly_HH_Income.max())
print ('Minimum Monthly HH Income would be : ', Mthly_HH_Income.min())
print ('Average Monthly HH Income would be : ', Mthly_HH_Income.mean())
print ('Standard Deviation of Monthly HH Income would be : ', Mthly_HH_Income.std())
print ('Variance of Monthly HH Income would be : ', Mthly_HH_Income.var())
print('')
print ('Median of Monthly HH Income would be : ', np.median(Mthly_HH_Income))
print ('Quartile 50 % value would be : ', scoreatpercentile(Mthly_HH_Income, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(Mthly_HH_Income, 75))
print ('Mode of Monthly HH Income would be : ', stats.mode(Mthly_HH_Income))
# Out:
# Maximum Monthly HH Income would be :  100000
# Minimum Monthly HH Income would be :  5000
# Average Monthly HH Income would be :  41558.0
# Standard Deviation of Monthly HH Income would be :  25835.611779092826
# Variance of Monthly HH Income would be :  667478836.0
#
# Median of Monthly HH Income would be :  35000.0
# Quartile 50 % value would be :  35000.0
# Quartile 75% value would be :  50375.0
# Mode of Monthly HH Income would be :  ModeResult(mode=array([45000], dtype=int64), count=array([4]))

# %% [markdown]
# 2. Mthly HH Expense

# %%
Mthly_HH_Expense = Dataset['Mthly_HH_Expense'].values
print ('Maximum Monthly HH Expense would be : ', Mthly_HH_Expense.max())
print ('Minimum Monthly HH Expense would be : ', Mthly_HH_Expense.min())
print ('Average Monthly HH Expense would be : ', Mthly_HH_Expense.mean())
print ('Standard Deviation of Monthly HH Expense would be : ', Mthly_HH_Expense.std())
print ('Variance of Monthly HH Expense would be : ', Mthly_HH_Expense.var())
print('')
print ('Median of Monthly HH Expense would be : ', np.median(Mthly_HH_Expense))
print ('Quartile 50 % value would be : ', scoreatpercentile(Mthly_HH_Expense, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(Mthly_HH_Expense, 75))
print ('Mode of Monthly HH Expense would be : ', stats.mode(Mthly_HH_Expense))
# Out:
# Maximum Monthly HH Expense would be :  50000
# Minimum Monthly HH Expense would be :  2000
# Average Monthly HH Expense would be :  18818.0
# Standard Deviation of Monthly HH Expense would be :  11968.704023410388
# Variance of Monthly HH Expense would be :  143249876.0
#
# Median of Monthly HH Expense would be :  15500.0
# Quartile 50 % value would be :  15500.0
# Quartile 75% value would be :  25000.0
# Mode of Monthly HH Expense would be :  ModeResult(mode=array([25000], dtype=int64), count=array([8]))

# %% [markdown]
# 3. No of Fly Members

# %%
No_of_Fly_Members = Dataset['No_of_Fly_Members'].values
print ('Maximum No of Fly Members would be : ', No_of_Fly_Members.max())
print ('Minimum No of Fly Members would be : ', No_of_Fly_Members.min())
print ('Average No of Fly Members would be : ', No_of_Fly_Members.mean())
print ('Standard Deviation of No of Fly Members would be : ', No_of_Fly_Members.std())
print ('Variance of No of Fly Members would be : ', No_of_Fly_Members.var())
print('')
print ('Median of No of Fly Members would be : ', np.median(No_of_Fly_Members))
print ('Quartile 50 % value would be : ', scoreatpercentile(No_of_Fly_Members, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(No_of_Fly_Members, 75))
print ('Mode of No of Fly Members would be : ', stats.mode(No_of_Fly_Members))
# Out:
# Maximum No of Fly Members would be :  7
# Minimum No of Fly Members would be :  1
# Average No of Fly Members would be :  4.06
# Standard Deviation of No of Fly Members would be :  1.502131818450032
# Variance of No of Fly Members would be :  2.2564
#
# Median of No of Fly Members would be :  4.0
# Quartile 50 % value would be :  4.0
# Quartile 75% value would be :  5.0
# Mode of No of Fly Members would be :  ModeResult(mode=array([4], dtype=int64), count=array([15]))

# %% [markdown]
# 4. Emi or Rent Amt

# %%
Emi_or_Rent_Amt = Dataset['Emi_or_Rent_Amt'].values
print ('Maximum Emi or Rent Amt would be : ', Emi_or_Rent_Amt.max())
print ('Minimum Emi or Rent Amt would be : ', Emi_or_Rent_Amt.min())
print ('Average Emi or Rent Amt would be : ', Emi_or_Rent_Amt.mean())
print ('Standard Deviation of Emi or Rent Amt would be : ', Emi_or_Rent_Amt.std())
print ('Variance of Emi or Rent Amt would be : ', Emi_or_Rent_Amt.var())
print('')
print ('Median of Emi or Rent Amt would be : ', np.median(Emi_or_Rent_Amt))
print ('Quartile 50 % value would be : ', scoreatpercentile(Emi_or_Rent_Amt, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(Emi_or_Rent_Amt, 75))
# Out:
# Maximum Emi or Rent Amt would be :  35000
# Minimum Emi or Rent Amt would be :  0
# Average Emi or Rent Amt would be :  3060.0
# Standard Deviation of Emi or Rent Amt would be :  6178.705366013175
# Variance of Emi or Rent Amt would be :  38176400.0
#
# Median of Emi or Rent Amt would be :  0.0
# Quartile 50 % value would be :  0.0
# Quartile 75% value would be :  3500.0

# %% [markdown]
# 5. Annual HH Income

# %%
Annual_HH_Income = Dataset['Annual_HH_Income'].values
print ('Maximum Annual HH Income would be : ', Annual_HH_Income.max())
print ('Minimum Annual HH Income would be : ', Annual_HH_Income.min())
print ('Average Annual HH Income would be : ', Annual_HH_Income.mean())
print ('Standard Deviation of Annual HH Income would be : ', Annual_HH_Income.std())
print ('Variance of Annual HH Income would be : ', Annual_HH_Income.var())
print('')
print ('Median of Annual HH Income would be : ', np.median(Annual_HH_Income))
print ('Quartile 50 % value would be : ', scoreatpercentile(Annual_HH_Income, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(Annual_HH_Income, 75))
# Out:
# Maximum Annual HH Income would be :  1404000
# Minimum Annual HH Income would be :  64200
# Average Annual HH Income would be :  490019.04
# Standard Deviation of Annual HH Income would be :  316918.2653145104
# Variance of Annual HH Income would be :  100437186889.9584
#
# Median of Annual HH Income would be :  447420.0
# Quartile 50 % value would be :  447420.0
# Quartile 75% value would be :  594720.0

# %% [markdown]
# 6. Highest Qualified Member
#
# We have categorical values here.

# %%
from sklearn.preprocessing import LabelEncoder
Encoder = LabelEncoder()
Highest_Qualified_Member = Encoder.fit_transform(Dataset['Highest_Qualified_Member'])
Dataset['Highest_Qualified_Member'] = Highest_Qualified_Member

# %%
Dataset.head(30)
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %% [markdown]
# Graduate = 0
# Illiterate = 1
# Post-graduate = 2
# Professional = 3
# Undergraduate = 4

# %%
Highest_Qualified_Member = Dataset['Highest_Qualified_Member'].values
print ('Maximum No of Highest Qualified Member would be : ', Highest_Qualified_Member.max())
print ('Minimum No Highest Qualified Member would be : ', Highest_Qualified_Member.min())
print ('Average No of Highest Qualified Member would be : ', Highest_Qualified_Member.mean())
print ('Standard Deviation of Highest Qualified Member would be : ', Highest_Qualified_Member.std())
print ('Variance of Highest Qualified Member would be : ', Highest_Qualified_Member.var())
print('')
print ('Median of Highest Qualified Member would be : ', np.median(Highest_Qualified_Member))
print ('Quartile 50 % value would be : ', scoreatpercentile(Highest_Qualified_Member, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(Highest_Qualified_Member, 75))
# Out:
# Maximum No of Highest Qualified Member would be :  4
# Minimum No Highest Qualified Member would be :  0
# Average No of Highest Qualified Member would be :  1.74
# Standard Deviation of Highest Qualified Member would be :  1.5976232346833217
# Variance of Highest Qualified Member would be :  2.5524
#
# Median of Highest Qualified Member would be :  2.0
# Quartile 50 % value would be :  2.0
# Quartile 75% value would be :  3.0

# %% [markdown]
# 7. No of Earning Members

# %%
No_of_Earning_Members = Dataset['No_of_Earning_Members'].values
print ('Maximum No of Earning Members would be : ', No_of_Earning_Members.max())
print ('Minimum No of Earning Members would be : ', No_of_Earning_Members.min())
print ('Average No of Earning Members would be : ', No_of_Earning_Members.mean())
print ('Standard Deviation of No of Earning Members would be : ', No_of_Earning_Members.std())
print ('Variance of No of Earning Members would be : ', No_of_Earning_Members.var())
print('')
print ('Median of No of Earning Members would be : ', np.median(No_of_Earning_Members))
print ('Quartile 50 % value would be : ', scoreatpercentile(No_of_Earning_Members, 50))
print ('Quartile 75% value would be : ', scoreatpercentile(No_of_Earning_Members, 75))
# Out:
# Maximum No of Earning Members would be :  4
# Minimum No of Earning Members would be :  1
# Average No of Earning Members would be :  1.46
# Standard Deviation of No of Earning Members would be :  0.72691127381545
# Variance of No of Earning Members would be :  0.5284
#
# Median of No of Earning Members would be :  1.0
# Quartile 50 % value would be :  1.0
# Quartile 75% value would be :  2.0

# %% [markdown]
# **Finding correlation**

# %%
sns.pairplot(Dataset)
plt.show()

# %% [markdown]
# **ANALYSIS** :
# 1. **Monthly HH Income & Monthly HH Expense** - Most of the data points lie in the range of Monthly HH Income < 50,000 and have expense < 30,000. If Monthly HH Income rises, expenses rises drastically.
# 2. **Monthly HH Income & No. of fly members** - Sparse datapoints. For Monthly HH Income < 50,000 we see alot of scattered points but for income > 50,000, average fly members could be around 4-7.
# 3. **Monthly HH Income & EMI/Rent amount** - Mostly it is very less and few outliers are there.
# 4. **Monthly HH Income & Annual Income** - We can see **almost** a linear relationship here ( Y = MX + C )
# 5. **Monthly HH Income & Highest qualified member** - For Monthly HH Income < 50,000, we can see majority of points are either  0 (Graduate) or 4 (Undergraduate) which makes sense. For income > 50,000 They are either 2 (Post-graduate) or 3 (Professional) which makes sense as well.
# 6. **Monthly HH Income & Number of earning members** - For income < 50,000, we can find mostly 1-2 people and for income > 50,000 the datapoints are again scattered ranging from 1-3.

# %%
sns.heatmap(Dataset)
plt.show()

# %% [markdown]
# Plotting some Regression plot to obtain the best fitted line

# %%
sns.regplot(x = Dataset["Mthly_HH_Income"], y = Dataset["Mthly_HH_Expense"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='Mthly_HH_Expense'>

# %%
sns.regplot(x = Dataset["Mthly_HH_Income"], y = Dataset["No_of_Fly_Members"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='No_of_Fly_Members'>

# %%
sns.regplot(x = Dataset["Mthly_HH_Income"], y = Dataset["Emi_or_Rent_Amt"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='Emi_or_Rent_Amt'>

# %%
sns.regplot(x = Dataset["Mthly_HH_Income"], y = Dataset["Annual_HH_Income"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='Annual_HH_Income'>

# %%
sns.regplot(x = Dataset["Mthly_HH_Income"], y = Dataset["No_of_Earning_Members"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='No_of_Earning_Members'>

# %%
sns.regplot(x = Dataset["Mthly_HH_Income"], y = Dataset["No_of_Earning_Members"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='No_of_Earning_Members'>

# %%
sns.kdeplot(x = Dataset["Mthly_HH_Income"], y = Dataset["Mthly_HH_Expense"])
# Out:
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='Mthly_HH_Expense'>

# %% [markdown]
# This is a **density contour** plot. I had made one of these to find the maximum density of monthly expense would be from **0-30,000**  when income would be from **0-50,000**

# %%
x = Dataset["Mthly_HH_Income"]
y = Dataset["Mthly_HH_Expense"]
z = Dataset["No_of_Fly_Members"]

plt.figure()

plt.subplot(121)
plt.plot(x, y, color = 'green', marker = '*', linestyle = 'dashed', linewidth = 1, markersize = 4)

plt.subplot(122)
plt.plot(x, z, color = 'green', marker = '*', linestyle = 'dashed', linewidth = 1, markersize = 4)

# %%
def QQ_plot(data, measure):
    fig = plt.figure(figsize = (20,7))
    (mu, sigma) = norm.fit(data)
    
    fig1 = fig.add_subplot(121)
    sns.distplot(data, fit = norm)
    fig1.set_title(measure + ' Distribution ( mean = {:.2f} and standard deviation = {:.2f} )'.format(mu, sigma), loc = 'center')
    fig1.set_xlabel(measure)
    fig1.set_ylabel('Frequency')

    plt.tight_layout()
    plt.show()

# %%
QQ_plot(Dataset.Mthly_HH_Income, 'Mthly_HH_Income')
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Outcome :
# Mean Income would be : 41,558.0
# Standard deviation would be : 25,835.61

# %% [markdown]
# ### Understanding our data through QQ-Plots
# The quantile-quantile (q-q) plot is a graphical technique for determining if two data sets come from populations with a common distribution. A q-q plot is a plot of the quantiles of the first data set against the quantiles of the second data set.

# %% [markdown]
# 1. Mthly_HH_Income

# %%
Mthly_HH_Income = Dataset.Mthly_HH_Income
sns.distplot(Mthly_HH_Income)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Mthly_HH_Income', ylabel='Density'>

# %%
A = probplot(Mthly_HH_Income,dist='norm',plot=pylab)
pylab.show(A)

# %% [markdown]
# 2. Mthly_HH_Expense

# %%
Mthly_HH_Expense = Dataset.Mthly_HH_Expense
sns.distplot(Mthly_HH_Expense)
B = probplot(Mthly_HH_Expense,dist='norm',plot=pylab)
pylab.show(B)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 3. No_of_Fly_Members

# %%
No_of_Fly_Members = Dataset.No_of_Fly_Members
sns.distplot(No_of_Fly_Members)
C = probplot(No_of_Fly_Members,dist='norm',plot=pylab)
pylab.show(C)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 4. Emi_or_Rent_Amt

# %%
Emi_or_Rent_Amt = Dataset.Emi_or_Rent_Amt
sns.distplot(Emi_or_Rent_Amt)
D = probplot(Emi_or_Rent_Amt,dist='norm',plot=pylab)
pylab.show(D)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 5. Annual_HH_Income

# %%
Annual_HH_Income = Dataset.Annual_HH_Income
sns.distplot(Annual_HH_Income)
E = probplot(Annual_HH_Income,dist='norm',plot=pylab)
pylab.show(E)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 6. Highest_Qualified_Member

# %%
Highest_Qualified_Member = Dataset.Highest_Qualified_Member
sns.distplot(Highest_Qualified_Member)
F = probplot(Highest_Qualified_Member,dist='norm',plot=pylab)
pylab.show(F)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 7. No_of_Earning_Members

# %%
No_of_Earning_Members = Dataset.No_of_Earning_Members
sns.distplot(No_of_Earning_Members)
G = probplot(No_of_Earning_Members , dist = 'norm' , plot = pylab)
pylab.show(G)
# Out:
# D:\Anaconda\envs\tf\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
